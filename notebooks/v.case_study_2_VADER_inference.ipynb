# %%
# Install the VADER Sentiment library silently
# !pip install vaderSentiment -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.0 MB/s eta 0:00:00

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Exact verified Google Sheet ID
SHEET_ID = "1S-MaUYM54ztOBw-rZkmKxSzH0LAPaFjJe4Der5Rl4jc"
# Exact tab name
SHEET_NAME = "fact_viral_marketing_trends"

# This URL forces Google Sheets to stream the live data tab as an automatic CSV stream
url = f"https://docs.google.com/spreadsheets/d/{SHEET_ID}/gviz/tq?tqx=out:csv&sheet={SHEET_NAME}"

# Stream the table straight into the active pandas DataFrame
df = pd.read_csv(url)

# 1. Clean the staging dataframe structure natively
df = df[['trend_id', 'brand_partner', 'campaign_type', 'placement_driver', 'raw_consumer_text']].dropna(subset=['raw_consumer_text'])

# 2. Instantiate and permanently patch the analyzer BEFORE the execution loop
analyzer = SentimentIntensityAnalyzer()

slang_lexicon_patch = {
    'flex': 3.5, 'magic': 3.0, 'melanin': 2.0, 'ate': 3.5, 'crumbs': -1.0,
    'baddie': 2.5, 'it-girl': 3.5, 'meta-humor': 2.5, 'skepticism': -0.5, 'awe': 3.5
}
analyzer.lexicon.update(slang_lexicon_patch)

# 3. Define the metrics logic referencing the pre-patched cache
def get_vader_metrics(text):
    text_str = str(text)
    polarity = analyzer.polarity_scores(text_str)
    return pd.Series([polarity['pos'], polarity['neu'], polarity['compound']])

# 4. Simultaneously score all 16 multi-season rows
df[['positive_score', 'neutral_score', 'compound_score']] = df['raw_consumer_text'].apply(get_vader_metrics)

print("🎯 Pipeline complete: All 16 records scored with permanent slang logic constraints!")
df.head(16)
# Out:
# 🎯 Pipeline complete: All 16 records scored with permanent slang logic constraints!
#     trend_id            brand_partner                  campaign_type  \
# 0          1                   Cécred           Hair & Personal Care
# 1          2                  Spotify  Digital Media & Entertainment
# 2          3                    Avène             Beauty & Cosmetics
# 3          4                  Dunkin’                Food & Beverage
# 4          5        Charlotte Tilbury               Luxury Cosmetics
# 5          6       NYX & SheaMoisture             Beauty & Hair Care
# 6          7             Shark Beauty         Hair Tools & Hair Care
# 7          8      Maybelline New York            Corporate Cosmetics
# 8          9         Skylar Fragrance      Luxury Fragrance & Retail
# 9         10  NYX Professional Makeup             Beauty & Cosmetics
# 10        11            Agua de Kefir                Food & Beverage
# 11        12               Sweetgreen             Fast-Casual Dining
# 12        13              Jose Cuervo                 Wine & Spirits
# 13        14     Independent Modeling             Fashion & Speaking
# 14        15          Barbie / Mattel           Toys & Entertainment
# 15        16                    Poppi                       Beverage
#
#                      placement_driver  \
# 0               Season 6 Reunion Drop
# 1               Custom Villa Playlist
# 2            Skincare Routine Request
# 3               $6 Meal Deal Campaign
# 4            Digital Makeup Tutorials
# 5              Post-Villa Style Surge
# 6           FlexStyle Routine Rollout
# 7          Peacock Summer Integration
# 8         Chief Creative Officer Hire
# 9   Season 7 Finale Nicolandria Combo
# 10       Post-Villa Press Wellness Ad
# 11          ZCON "Ranchy Baddie Bowl"
# 12      Summer Entertainment Campaign
# 13   Post-Split Pivot (Orlando to LA)
# 14   Coachella Weekend 1 Experiential
# 15    Punch Pop X Love Island Release
#
#                                     raw_consumer_text  positive_score  \
# 0   Extreme pride regarding high-end recognition o...           0.197
# 1   High amusement and hype over viral music comme...           0.200
# 2   Massive organic buy-rates. Fans flooding retai...           0.224
# 3   Universal nostalgia. Obsessed with meta-humor,...           0.265
# 4   Visual awe over transition from standard influ...           0.310
# 5   Intense community support from natural hair cr...           0.481
# 6   Praised for natural on-camera charisma. Commen...           0.655
# 7   Massive comedic hit. Soap-opera style allowed ...           0.231
# 8   Initial Reddit perfume community skepticism sh...           0.300
# 9   Massive viral sell-out buzz. Mixed with mild R...           0.000
# 10  High fan amusement over the "steamy" tone. Jok...           0.405
# 11  Intense Southern pride over Alabama native col...           0.252
# 12  Praised for high production value. Reddit vali...           0.429
# 13  Huge wave of community empowerment and Haitian...           0.281
# 14  Complete alignment of brand aesthetic. Visual ...           0.273
# 15  High visibility via national Target retail dis...           0.000
#
#     neutral_score  compound_score
# 0           0.803          0.4005
# 1           0.800          0.3612
# 2           0.776          0.3818
# 3           0.606          0.4215
# 4           0.690          0.6705
# 5           0.519          0.6705
# 6           0.345          0.8860
# 7           0.769          0.4019
# 8           0.600          0.6124
# 9           0.889         -0.1280
# 10          0.595          0.7003
# 11          0.748          0.4019
# 12          0.571          0.7579
# 13          0.719          0.5719
# 14          0.727          0.6705
# 15          1.000          0.0000

# %%
import pandas as pd
from google.colab import auth
import gspread
from google.auth import default

# 1. Authenticate the Google User Session (Click the quick pop-up window that appears)
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# 2. Open the specific master workbook using its exact title
spreadsheet_name = "case_study_2_influencer_syndication_loops"
wb = gc.open(spreadsheet_name)

# 3. Target the exact production database tab name
sheet_name = "fact_viral_marketing_trends"
ws = wb.worksheet(sheet_name)

# 4. Convert the finished VADER DataFrame back into a clean list format
# This preserves your custom headers and prevents formatting layout breaks
updated_data = [df.columns.values.tolist()] + df.values.tolist()

# 5. Overwrite the spreadsheet grid starting from row 1, column 1
ws.update(values=updated_data, range_name="A1")

print("🚀 Pipeline complete: All 16 VADER sentiment scores successfully exported back into the master Google Sheet database!")
# Out:
# 🚀 Pipeline complete: All 16 VADER sentiment scores successfully exported back into the master Google Sheet database!
